# %% [markdown]
# SOCIO ECONOMIC
# - median income (Census data)
# - % of unemployment (Census data)
# - % of renters (Census data)
# - % of rent burdened (>30%) and severe burdened (>50%)

# %%
from census import Census
import pandas as pd
from us import states

import censusgeocode as cg

import math

from shapely.geometry import Point, Polygon
import geopandas as gpd

# %%
api_key = '13c056d339e329f0a4fbef4384e3667e505a55da'

# %%
c = Census("13c056d339e329f0a4fbef4384e3667e505a55da", year=2015)

# %% [markdown]
# # Define Address and Study Area

# %%
# addr = "228 Boerum St. Brooklyn, NY"
addr = "373 VAN BRUNT STREET Brooklyn, NY"
# addr = "1 EAST LOOP ROAD"
addr_census_result = cg.onelineaddress(addr)

# %%
# get coordinates of addr
addr_point = Point(addr_census_result[0]['coordinates']['x'], addr_census_result[0]['coordinates']['y'])

# %%
# get study area pluto data
radius = 0.5 # miles
study_area = addr_point.buffer(radius / 69)
study_area_polygon = Polygon(study_area.exterior.coords)

# %% [markdown]
# # Load Census block group shape file and Filter out blocks in study area

# %%
# Load census block groups shape file
block_groups = gpd.read_file('data/ny_block_groups/tl_2015_36_bg.shp')

# %%
print(len(block_groups))
block_groups.head()
# Out:
# 15463
#   STATEFP COUNTYFP TRACTCE BLKGRPCE         GEOID       NAMELSAD  MTFCC  \
# 0      36      005  017500        2  360050175002  Block Group 2  G5030
# 1      36      005  014100        1  360050141001  Block Group 1  G5030
# 2      36      005  014500        1  360050145001  Block Group 1  G5030
# 3      36      005  007500        2  360050075002  Block Group 2  G5030
# 4      36      005  041800        1  360050418001  Block Group 1  G5030
#
#   FUNCSTAT   ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S   23694       0  +40.8296335  -073.9152037
# 1        S   55934       0  +40.8245444  -073.9131209
# 2        S   47026       0  +40.8309816  -073.9050870
# 3        S  109058       0  +40.8202395  -073.9080678
# 4        S  140793       0  +40.8989195  -073.8564428
#
#                                             geometry
# 0  POLYGON ((-73.915699 40.830536, -73.914852 40....
# 1  POLYGON ((-73.916614 40.82499199999999, -73.91...
# 2  POLYGON ((-73.90584 40.831059, -73.905051 40.8...
# 3  POLYGON ((-73.910348 40.819947, -73.910219 40....
# 4  POLYGON ((-73.862875 40.895154, -73.861465 40....

# %% [markdown]
# # Map the census block groups

# %%
block_groups_study_area = block_groups[block_groups.apply(lambda row: study_area_polygon.contains(row['geometry'].centroid), axis=1)]

# %%
import folium

addr_location = (addr_point.y, addr_point.x)
m = folium.Map(location=addr_location,zoom_start=14,tiles="Stamen Toner")

folium.Circle(addr_location, radius=radius * 1609.34).add_to(m)

folium.GeoJson(
    block_groups_study_area['geometry'],
    name='geojson'
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Calculate population of Study area

# %%
block_groups_study_area_data = pd.DataFrame(block_groups_study_area.apply(lambda row: c.acs5.state_county_blockgroup(("NAME", "B19013_001E", "B01003_001E"), row['STATEFP'], row['COUNTYFP'], row['BLKGRPCE'], row['TRACTCE']), axis=1))

# %%
block_groups_study_area_data
# Out:
#                                                       0
# 7268  [{'NAME': 'Block Group 1, Census Tract 53, Kin...
# 7501  [{'NAME': 'Block Group 2, Census Tract 53, Kin...
# 7502  [{'NAME': 'Block Group 3, Census Tract 53, Kin...
# 7503  [{'NAME': 'Block Group 4, Census Tract 53, Kin...
# 9875  [{'NAME': 'Block Group 1, Census Tract 59, Kin...
# 9926  [{'NAME': 'Block Group 1, Census Tract 85, Kin...

# %%
block_group_study_area_data = []
for block_group in block_groups_study_area.iterrows():
    bg = block_group[1]
    bg_data = c.acs5.state_county_blockgroup(("NAME", "B19013_001E", "B01003_001E"), bg['STATEFP'], bg['COUNTYFP'], bg['BLKGRPCE'], bg['TRACTCE'])
    bg_data = bg_data[0]
    bg_data['index'] = bg.name
    block_group_study_area_data.append(bg_data)
block_group_study_area_data = pd.DataFrame.from_dict(block_group_study_area_data)
block_group_study_area_data.set_index('index')

census_mapper = {'B01003_001E': 'population', 'B19013_001E': 'income'}
block_group_study_area_data = block_group_study_area_data.rename(census_mapper, axis='columns')

# %%
# Drop nans for now.. this makes calculations easier
block_group_study_area_data = block_group_study_area_data.dropna()
block_group_study_area_data
# Out:
#    population    income                                               NAME  \
# 1      1198.0   63000.0  Block Group 2, Census Tract 53, Kings County, ...
# 2       468.0   70795.0  Block Group 3, Census Tract 53, Kings County, ...
# 3       352.0  117625.0  Block Group 4, Census Tract 53, Kings County, ...
# 4       789.0   55833.0  Block Group 1, Census Tract 59, Kings County, ...
# 5      3113.0   14879.0  Block Group 1, Census Tract 85, Kings County, ...
#
#   block group county  index state   tract
# 1           2    047   7501    36  005300
# 2           3    047   7502    36  005300
# 3           4    047   7503    36  005300
# 4           1    047   9875    36  005900
# 5           1    047   9926    36  008500

# %%
total_population = block_group_study_area_data['population'].sum()
print("Total population of Study Area: {}".format(total_population))
# Out:
# Total population of Study Area: 5920.0

# %%
# Map this?... not working yet

folium.Choropleth(
    geo_data=block_groups_study_area['geometry'],
    name='choropleth',
    data=block_group_study_area_data,
    columns=['block group', 'population'],
    key_on='index',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Calculate Weighted median of Study area income

# %%
weighted_median_income = 0

for block_group in block_group_study_area_data.iterrows():
    bg = block_group[1]
    weighted_median_income += bg['income'] * bg['population']
    
weighted_median_income = weighted_median_income / total_population    

print("Weighted median of Study area income: {}".format(weighted_median_income))
# Out:
# Weighted median of Study area income: 40604.83513513514

# %%
# map this?
