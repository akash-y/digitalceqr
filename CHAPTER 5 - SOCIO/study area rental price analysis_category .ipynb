# %%
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt

# %matplotlib inline

# %% [markdown]
# ### Data downloaded from streeteasy, and first plot median asking rent for studio

# %% [markdown]
# ## Studio

# %%
studio = pd.read_csv('medianAskingRent_Studio.csv')
studio.head()
# Out:
#               areaName    Borough   areaType  2010-01  2010-02  2010-03  \
# 0         All Downtown  Manhattan  submarket   2350.0   2300.0   2200.0
# 1          All Midtown  Manhattan  submarket   2000.0   1995.0   1995.0
# 2  All Upper East Side  Manhattan  submarket   1750.0   1750.0   1750.0
# 3  All Upper Manhattan  Manhattan  submarket   1175.0   1150.0   1150.0
# 4  All Upper West Side  Manhattan  submarket   1800.0   1800.0   1795.0
#
#    2010-04  2010-05  2010-06  2010-07   ...     2018-07  2018-08  2018-09  \
# 0   2250.0   2300.0   2300.0   2290.0   ...      2795.0   2800.0   2850.0
# 1   2000.0   2000.0   2000.0   2050.0   ...      2595.0   2595.0   2575.0
# 2   1780.0   1800.0   1750.0   1750.0   ...      2050.0   2099.0   2100.0
# 3   1150.0   1150.0   1195.0   1250.0   ...      1750.0   1795.0   1795.0
# 4   1800.0   1895.0   1895.0   1800.0   ...      2300.0   2295.0   2200.0
#
#    2018-10  2018-11  2018-12  2019-01  2019-02  2019-03  2019-04
# ...

# %% [markdown]
# #### Data contains rental price in many area, drop other area and keep the study area. There are many nan in RedHook data, so we also drop it.

# %%
studio_study= studio.loc[oneb['areaName'] == 'Red Hook']
studio_study2 = studio_study.dropna(axis=1, how="all")

# %%
studio_study3=studio_study2.drop(['Borough','areaType'], axis=1)
studio_study4 = studio_study3.set_index(['areaName'])
studio_study4
# Out:
#           2014-10  2017-06  2017-07  2017-08  2017-10  2018-04  2018-12
# areaName
# Red Hook   2500.0   2300.0   2400.0   2350.0   2775.0   1800.0   3500.0

# %%
df_studio= studio_study4.T

# %%
df = df_studio.rename(columns={'areaName': 'year', 'Red Hook': 'medianAskingRent'})

# %%
ax =df [['medianAskingRent']].plot(kind='bar', title ="median asking rental price in Redhook (Studio)", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("median asking rental price", fontsize=12)
plt.show()

# %% [markdown]
# ## One-Bedroom

# %%
oneb = pd.read_csv('medianAskingRent_Onebd.csv')
oneb.head()
# Out:
#               areaName    Borough   areaType  2010-01  2010-02  2010-03  \
# 0         All Downtown  Manhattan  submarket   2995.0   2950.0   2900.0
# 1          All Midtown  Manhattan  submarket   2800.0   2800.0   2850.0
# 2  All Upper East Side  Manhattan  submarket   2350.0   2300.0   2350.0
# 3  All Upper Manhattan  Manhattan  submarket   1500.0   1516.0   1545.0
# 4  All Upper West Side  Manhattan  submarket   2600.0   2550.0   2495.0
#
#    2010-04  2010-05  2010-06  2010-07   ...     2018-07  2018-08  2018-09  \
# 0   2975.0   2995.0   3000.0   3000.0   ...      3500.0   3550.0   3599.0
# 1   2895.0   2900.0   2990.0   3000.0   ...      3495.0   3500.0   3500.0
# 2   2470.0   2500.0   2500.0   2500.0   ...      2778.0   2775.0   2780.0
# 3   1516.0   1550.0   1575.0   1550.0   ...      1995.0   1959.0   1950.0
# 4   2500.0   2500.0   2600.0   2600.0   ...      3050.0   3050.0   3100.0
#
#    2018-10  2018-11  2018-12  2019-01  2019-02  2019-03  2019-04
# ...

# %%
oneb_study= oneb.loc[oneb['areaName'] == 'Red Hook']
oneb_study2 = oneb_study.dropna(axis=1, how="all")

# %%
oneb_study3=oneb_study2.drop(['Borough','areaType'], axis=1)
oneb_study4 = oneb_study3.set_index(['areaName'])
oneb_study4
# Out:
#           2010-10  2010-11  2012-03  2012-05  2012-06  2013-01  2014-02  \
# areaName
# Red Hook   1450.0   1488.0   2000.0   1950.0   2000.0   2000.0   1900.0
#
#           2014-03  2014-04  2014-05   ...     2017-09  2018-05  2018-06  \
# areaName                              ...
# Red Hook   2200.0   2400.0   2400.0   ...      2175.0   2000.0   1950.0
#
#           2018-07  2018-08  2018-09  2018-10  2018-12  2019-01  2019-02
# areaName
# Red Hook   2000.0   1800.0   2400.0   2400.0   2642.0   2113.0   2150.0
#
# [1 rows x 43 columns]

# %%
df_oneb= oneb_study4.T

# %%
df1 =df_oneb.rename(columns={'areaName': 'year', 'Red Hook': 'medianAskingRent'})

# %%
df1
# Out:
# areaName  medianAskingRent
# 2010-10             1450.0
# 2010-11             1488.0
# 2012-03             2000.0
# 2012-05             1950.0
# 2012-06             2000.0
# 2013-01             2000.0
# 2014-02             1900.0
# 2014-03             2200.0
# 2014-04             2400.0
# 2014-05             2400.0
# 2014-07             2300.0
# 2014-08             2200.0
# 2014-09             2150.0
# 2014-10             1895.0
# 2015-02             1800.0
# 2015-03             2000.0
# 2015-04             1900.0
# 2015-05             2400.0
# 2015-06             2000.0
# 2015-07             2000.0
# 2015-08             2200.0
# 2015-09             1899.0
# 2015-10             2399.0
# 2015-11             2450.0
# 2015-12             2450.0
# 2016-01             2387.0
# 2016-05             2300.0
# 2016-06             2200.0
# 2016-12             2200.0
# 2017-01             2300.0
# 2017-05             2585.0
# 2017-06             2499.0
# 2017-07             2500.0
# ...

# %%
ax =df1[['medianAskingRent']].plot(kind='bar', title ="median asking rental price in Redhook (Onebedroom)", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("median asking rental price", fontsize=12)
plt.show()

# %%
f, ax = plt.subplots(figsize=(20,8))
df1['medianAskingRent'].plot(alpha=1,linewidth=2,ax=ax,label='medianAskingRent')
plt.title("median asking rental price in Redhook (Onebedroom)", fontsize=25)
plt.xlabel("Year", fontsize=15)
plt.ylabel("median asking rental price", fontsize=15)
plt.legend(prop={'size': 20})
plt.show()

# %% [markdown]
# ## Two Bedroom

# %%
twob = pd.read_csv('medianAskingRent_Twobd.csv')
twob.head()
# Out:
#               areaName    Borough   areaType  2010-01  2010-02  2010-03  \
# 0         All Downtown  Manhattan  submarket   4400.0   4450.0   4400.0
# 1          All Midtown  Manhattan  submarket   4700.0   4500.0   4500.0
# 2  All Upper East Side  Manhattan  submarket   3500.0   3650.0   3800.0
# 3  All Upper Manhattan  Manhattan  submarket   2000.0   1985.0   1950.0
# 4  All Upper West Side  Manhattan  submarket   4200.0   4100.0   4100.0
#
#    2010-04  2010-05  2010-06  2010-07   ...     2018-07  2018-08  2018-09  \
# 0   4400.0   4400.0   4295.0   4295.0   ...      4200.0   4200.0   4467.0
# 1   4495.0   4500.0   4500.0   4495.0   ...      4600.0   4708.0   4685.0
# 2   3950.0   3965.0   3900.0   3800.0   ...      3495.0   3495.0   3600.0
# 3   1950.0   1975.0   1975.0   2000.0   ...      2500.0   2495.0   2475.0
# 4   4498.0   4500.0   4500.0   3995.0   ...      4400.0   4500.0   4577.0
#
#    2018-10  2018-11  2018-12  2019-01  2019-02  2019-03  2019-04
# ...

# %%
twob_study= twob.loc[oneb['areaName'] == 'Red Hook']
twob_study2 = twob_study.dropna(axis=1, how="all")

# %%
twob_study3=twob_study2.drop(['Borough','areaType'], axis=1)
twob_study4 = twob_study3.set_index(['areaName'])
twob_study4
# Out:
#           2013-02  2014-05  2014-06  2014-07  2014-08  2014-09  2014-10  \
# areaName
# Red Hook   2100.0   3000.0   3000.0   3000.0   3000.0   2800.0   2700.0
#
#           2014-11  2014-12  2015-01   ...     2018-07  2018-08  2018-09  \
# areaName                              ...
# Red Hook   2875.0   2850.0   2800.0   ...      2575.0   2600.0   2700.0
#
#           2018-10  2018-11  2018-12  2019-01  2019-02  2019-03  2019-04
# areaName
# Red Hook   2500.0   2500.0   2678.0   2625.0   3000.0   3000.0   2597.0
#
# [1 rows x 61 columns]

# %%
df_twob= twob_study4.T

# %%
df2 =df_twob.rename(columns={'areaName': 'year', 'Red Hook': 'medianAskingRent'})

# %%
df2
# Out:
# areaName  medianAskingRent
# 2013-02             2100.0
# 2014-05             3000.0
# 2014-06             3000.0
# 2014-07             3000.0
# 2014-08             3000.0
# 2014-09             2800.0
# 2014-10             2700.0
# 2014-11             2875.0
# 2014-12             2850.0
# 2015-01             2800.0
# 2015-02             2300.0
# 2015-03             2600.0
# 2015-04             2600.0
# 2015-05             2300.0
# 2015-06             2400.0
# 2015-07             2300.0
# 2015-08             2000.0
# 2015-09             2200.0
# 2015-10             2500.0
# 2015-11             2350.0
# 2015-12             2465.0
# 2016-01             2465.0
# 2016-02             2599.0
# 2016-03             2725.0
# 2016-04             2825.0
# 2016-05             2800.0
# 2016-06             2500.0
# 2016-07             2750.0
# 2016-08             3500.0
# 2016-09             2925.0
# ...                    ...
# 2016-11             2700.0
# 2016-12             2450.0
# ...

# %%
ax =df2[['medianAskingRent']].plot(kind='bar', title ="median asking rental price in Redhook (twobedroom)", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("median asking rental price", fontsize=12)
plt.show()

# %%
f, ax = plt.subplots(figsize=(20,8))
df2['medianAskingRent'].plot(alpha=1,linewidth=2,ax=ax,label='medianAskingRent')
plt.title("median asking rental price in Redhook (twobedroom)", fontsize=25)
plt.xlabel("Year", fontsize=15)
plt.ylabel("median asking rental price", fontsize=15)
plt.legend(prop={'size': 20})
plt.show()

# %% [markdown]
# ## More than 3 Bedrooms

# %%
three = pd.read_csv('medianAskingRent_ThreePlusBd.csv')
three.head()
# Out:
#               areaName    Borough   areaType  2010-01  2010-02  2010-03  \
# 0         All Downtown  Manhattan  submarket   6700.0   6500.0   6500.0
# 1          All Midtown  Manhattan  submarket   7948.0   8000.0   6900.0
# 2  All Upper East Side  Manhattan  submarket   8950.0   9000.0   9900.0
# 3  All Upper Manhattan  Manhattan  submarket   2700.0   2673.0   2600.0
# 4  All Upper West Side  Manhattan  submarket   7000.0   7000.0   7000.0
#
#    2010-04  2010-05  2010-06  2010-07   ...     2018-07  2018-08  2018-09  \
# 0   6798.0   6798.0   6000.0   6000.0   ...      5898.0   6000.0   6000.0
# 1   5995.0   6500.0   7125.0   7500.0   ...      5760.0   5798.0   5955.0
# 2   8400.0   8100.0   7725.0   7500.0   ...      6650.0   6900.0   7973.0
# 3   2795.0   2800.0   2600.0   2600.0   ...      3295.0   3300.0   3208.0
# 4   7950.0   8995.0   8500.0   7225.0   ...      6000.0   6800.0   7000.0
#
#    2018-10  2018-11  2018-12  2019-01  2019-02  2019-03  2019-04
# ...

# %%
three_study= three.loc[oneb['areaName'] == 'Red Hook']
three_study2 = three_study.dropna(axis=1, how="all")

# %%
three_study3=three_study2.drop(['Borough','areaType'], axis=1)
three_study4 = three_study3.set_index(['areaName'])
three_study4
# Out:
#           2013-01  2013-05  2015-10  2015-11  2015-12  2016-01  2016-02  \
# areaName
# Red Hook   3000.0   2600.0   3550.0   3393.0   3300.0   3299.0   3300.0
#
#           2016-03  2016-04  2016-05   ...     2017-10  2017-11  2018-02  \
# areaName                              ...
# Red Hook   3300.0   3500.0   3300.0   ...      3495.0   3200.0   3625.0
#
#           2018-03  2018-04  2018-05  2018-08  2019-01  2019-03  2019-04
# areaName
# Red Hook   3450.0   3200.0   2975.0   3200.0   2800.0   3198.0   3175.0
#
# [1 rows x 29 columns]

# %%
df_threeb= three_study4.T

# %%
df3 =df_threeb.rename(columns={'areaName': 'year', 'Red Hook': 'medianAskingRent'})

# %%
df3
# Out:
# areaName  medianAskingRent
# 2013-01             3000.0
# 2013-05             2600.0
# 2015-10             3550.0
# 2015-11             3393.0
# 2015-12             3300.0
# 2016-01             3299.0
# 2016-02             3300.0
# 2016-03             3300.0
# 2016-04             3500.0
# 2016-05             3300.0
# 2016-06             3050.0
# 2016-07             3342.0
# 2016-09             3000.0
# 2017-03             3050.0
# 2017-04             2748.0
# 2017-06             3200.0
# 2017-07             3200.0
# 2017-08             3499.0
# 2017-09             3500.0
# 2017-10             3495.0
# 2017-11             3200.0
# 2018-02             3625.0
# 2018-03             3450.0
# 2018-04             3200.0
# 2018-05             2975.0
# 2018-08             3200.0
# 2019-01             2800.0
# 2019-03             3198.0
# 2019-04             3175.0

# %%
ax =df3[['medianAskingRent']].plot(kind='bar', title ="median asking rental price in Redhook (morethanthree)", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("median asking rental price", fontsize=12)
plt.show()

# %%
f, ax = plt.subplots(figsize=(20,8))
df3['medianAskingRent'].plot(alpha=1,linewidth=2,ax=ax,label='medianAskingRent')
plt.title("median asking rental price in Redhook (twobedroom)", fontsize=25)
plt.xlabel("Year", fontsize=15)
plt.ylabel("median asking rental price", fontsize=15)
plt.legend(prop={'size': 20})
plt.show()
