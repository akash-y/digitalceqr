# %%
import requests
import pandas as pd
import numpy as np

from __future__ import print_function, division
import matplotlib.pylab as pl
import seaborn as sns
sns.set_style('whitegrid')
import json

# Spatial
import geopandas as gpd
import fiona
import shapely

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nycTracts = gpd.GeoDataFrame.from_file("data/2010 Census Tracts/geo_export_224931c2-22f3-4618-850b-cbe10b3950b8.shp")
nycTracts = nycTracts[nycTracts.boro_name == 'Brooklyn']
# nycTracts = nycTracts.drop(['boro_code', 'boro_name'], axis=1)

print(nycTracts.shape)
nycTracts.head()
# Out:
# (760, 12)
#    boro_code boro_ct201 boro_name cdeligibil  ct2010 ctlabel ntacode  \
# 19         3    3000501  Brooklyn          I  000501    5.01    BK09
# 20         3    3002000  Brooklyn          I  002000      20    BK32
# 21         3    3004100  Brooklyn          I  004100      41    BK38
# 22         3    3005800  Brooklyn          E  005800      58    BK31
# 23         3    3006000  Brooklyn          I  006000      60    BK31
#
#                                              ntaname  puma    shape_area  \
# 19                      Brooklyn Heights-Cobble Hill  4004  9.015070e+05
# 20                                  Sunset Park West  4012  1.620770e+06
# 21  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill  4004  1.744094e+06
# 22                                         Bay Ridge  4013  2.080303e+06
# 23                                         Bay Ridge  4013  1.639074e+06
#
#      shape_leng                                           geometry
# ...

# %%
nycTracts[nycTracts['ntaname'] ==  'Carroll Gardens-Columbia Street-Red Hook']
# Out:
#      boro_code boro_ct201 boro_name cdeligibil  ct2010 ctlabel ntacode  \
# 24           3    3006700  Brooklyn          I  006700      67    BK33
# 620          3    3004900  Brooklyn          I  004900      49    BK33
# 943          3    3004500  Brooklyn          I  004500      45    BK33
# 1053         3    3008500  Brooklyn          E  008500      85    BK33
# 1624         3    3006300  Brooklyn          I  006300      63    BK33
# 1640         3    3006500  Brooklyn          I  006500      65    BK33
# 1900         3    3007500  Brooklyn          I  007500      75    BK33
# 1922         3    3007700  Brooklyn          I  007700      77    BK33
# 2138         3    3004700  Brooklyn          I  004700      47    BK33
# 2139         3    3005100  Brooklyn          I  005100      51    BK33
# 2144         3    3005300  Brooklyn          I  005300      53    BK33
# 2146         3    3005900  Brooklyn          I  005900      59    BK33
#
# ...
