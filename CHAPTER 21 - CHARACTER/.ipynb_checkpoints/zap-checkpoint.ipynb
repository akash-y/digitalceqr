# %% [markdown]
# # Zoning & Land Use Applications
#
# In this notebook I look at trends in Zoning & Land Use applications in NYC over time. I pulled the data from the NYC Planning Labs website:
#
# https://zap.planning.nyc.gov/projects?boroughs=Brooklyn&dcp_publicstatus=Completed%2CFiled%2CIn%20Public%20Review%2CUnknown
#
# The csv file read from in the following cells contains all ZAP applications regardless of borough, year, or project stage. Subsets of this data are made for Brooklyn and Red Hook.
#
# To get a sense of ZAP applications over time, I need to find other ways to get filing information since the data download provided on the NYC Planning Labs website doesn't include the initial filing date but only the "lastmilestonedate," which may be less informative.

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import geopandas as gpd
import shapely
from shapely.geometry import Polygon
from fiona.crs import from_epsg
import matplotlib.pylab as plt
import requests

# %% [markdown]
# ### ZAP for all of NYC

# %%
zap = pd.read_csv('data/primary_source_data/zap.csv')
zap.head()
# Out:
#      dcp_name dcp_ceqrnumber  \
# 0   2019R0029      19DCP168R
# 1  P2017R0360      19DCP150R
# 2   2019M0149      19DCP110Y
# 3   2019Y0061      18DOC001Y
# 4  P2018Q0042      19DCP003Q
#
#                                      dcp_projectname  \
# 0                                    347 Flagg Place
# 1                                   45 Douglas Court
# 2  Residential Tower Mechanical Voids Text Amendment
# 3          New York City Borough - Based Jail System
# 4                         47-15 34th Avenue Rezoning
#
#                                     dcp_projectbrief dcp_publicstatus_simp  \
# 0  This is a private application submitted by Joh...                 Filed
# 1  This is a private application by Convery Inves...      In Public Review
# 2  The Department of City Planning (DCP) proposes...      In Public Review
# 3  DOC is proposing to implement a borough-based ...      In Public Review
# 4  This is a private application by Ashley Young ...      In Public Review
#
#      dcp_borough dcp_ulurp_nonulurp dcp_communitydistricts  \
# 0  Staten Island              ULURP                   SI02
# 1  Staten Island              ULURP                   SI02
# 2      Manhattan              ULURP                   CY00
# 3       Citywide              ULURP    MN01;BK02;QN09;BX01
# 4         Queens              ULURP                   QN01
#
#                                          actiontypes  \
# 0                                                 ZA
# 1                                              ZA;ZA
# 2                                                 ZR
# 3  PS;ZM;ZS;ZS;ZS;PS;ZS;MM;ZS;ZS;ZS;ZS;ZS;ZS;ZS;H...
# 4  ZM;ZR;ZR;ZR;ZR;ZM;ZM;ZM;ZR;ZR;ZR;ZR;ZR;ZR;ZR;Z...
#
#       dcp_certifiedreferred dcp_femafloodzonea dcp_femafloodzonecoastala  \
# 0                       NaN              False                     False
# 1  2019-04-03T04:00:00.000Z              False                     False
# 2  2019-01-28T19:22:12.000Z              False                     False
# 3  2019-03-25T19:06:01.000Z              False                     False
# 4  2018-11-13T20:13:08.000Z              False                     False
#
#   dcp_femafloodzoneshadedx dcp_femafloodzonev  \
# 0                    False              False
# 1                    False              False
# 2                    False              False
# 3                    False              False
# 4                    False              False
#
#                                           applicants  \
# 0                                   John Elefterakis
# 1                    Peter Calvanico;Peter Calvanico
# 2                                                DCP
# 3  DOC;DOC;DOC;DOC;DOC;DOC;DOC;DOC;DOC;DOC;DOC;DO...
# 4  John Young Associates LLC;Ashley Young LLC;Ash...
#
#           lastmilestonedate  total_projects  has_centroid  \
# 0  2019-06-24T04:00:00.000Z           29013          True
# 1  2019-06-10T04:00:00.000Z           29013         False
# 2  2019-06-03T04:00:00.000Z           29013         False
# 3  2019-06-03T04:00:00.000Z           29013          True
# 4  2019-06-03T04:00:00.000Z           29013          True
#
#                                  center  \
# 0   [-74.109445117468,40.5839376852462]
# 1                           [null,null]
# 2                           [null,null]
# 3  [-73.9010519868197,40.7447616970607]
# 4  [-73.9148996827753,40.7542546716476]
#
#                                         ulurpnumbers
# 0                                      ["190351ZAR"]
# 1                        ["N190308ZAR","N190310ZAR"]
# 2                                     ["N190230ZRY"]
# 3  ["190104MMM","190116MMK","190117MMQ","190252MM...
# 4                        ["C180530ZMQ","N180529ZRQ"]

# %%
print("Number of projects in NYC missing latitude-longitude information for the project center: {}".format\
      (zap['center'].str.contains('null').sum()))
# Out:
# Number of projects in NYC missing latitude-longitude information for the project center: 8415

# %% [markdown]
# ### ZAP for Brooklyn only

# %%
zap_bk = zap[zap['dcp_borough']=='Brooklyn']
zap_bk.head()
# Out:
#       dcp_name dcp_ceqrnumber                  dcp_projectname  \
# 5   P2015K0351      16DCP134K     1010 Pacific Street Rezoning
# 6   P2013K0549      17DCP205K     1050 Pacific Street Rezoning
# 8   P2017K0429      18HPD104K  1921 Atlantic Ave - MWBE Site B
# 9   P2013K0364      18DCP104K            273 Avenue U Rezoning
# 10  P2016K0318      18DCP180K    3513 Atlantic Avenue Rezoning
#
#                                      dcp_projectbrief dcp_publicstatus_simp  \
# 5   This is a private application by 1010 Pacific ...      In Public Review
# 6   This is a private application by 1050 Pacific ...      In Public Review
# 8   This is an application by HPD requesting a UDA...      In Public Review
# 9   This is a private application by Ciarafour Rea...      In Public Review
# 10  This is a private application by Leemilt's Pet...      In Public Review
#
#    dcp_borough dcp_ulurp_nonulurp dcp_communitydistricts  \
# 5     Brooklyn              ULURP                   BK08
# 6     Brooklyn              ULURP                   BK08
# 8     Brooklyn              ULURP                   BK03
# 9     Brooklyn              ULURP                   BK11
# 10    Brooklyn              ULURP                   BK05
#
#                                           actiontypes  \
# 5   ZM;ZR;ZR;ZR;ZM;ZR;ZM;ZR;ZR;ZR;ZR;ZM;ZR;ZM;ZM;Z...
# 6   ZM;ZM;ZM;ZR;ZR;ZR;ZR;ZR;ZR;ZM;ZR;ZM;ZR;ZR;ZR;Z...
# 8   ZM;ZR;HA;ZM;HA;ZM;ZR;HU;HU;HU;HU;HU;ZM;HU;HU;H...
# 9   ZM;ZM;ZR;ZR;ZR;ZR;ZR;ZR;ZR;ZM;ZR;ZR;ZR;ZM;ZM;Z...
# 10                                           ZM;ZM;ZM
#
#        dcp_certifiedreferred dcp_femafloodzonea dcp_femafloodzonecoastala  \
# 5   2018-10-29T18:13:03.000Z              False                     False
# 6   2018-10-29T18:23:57.000Z              False                     False
# 8   2018-11-13T20:33:07.000Z              False                     False
# 9   2019-02-11T18:40:09.000Z              False                     False
# 10  2019-03-11T17:15:53.000Z              False                     False
#
#    dcp_femafloodzoneshadedx dcp_femafloodzonev  \
# 5                     False              False
# 6                     False              False
# 8                     False              False
# 9                     False              False
# 10                    False              False
#
#                                            applicants  \
# 5   1010 Pacific Street LLC;1010 Pacific Street LL...
# 6   Mark Rigerman;Mark Rigerman;Mark Rigerman;Mark...
# 8   HPD;HPD;HPD;HPD;HPD;HPD;HPD;HPD;HPD;HPD;HPD;HP...
# 9   CIARAFOUR REALTY, LLC;CIARAFOUR REALTY, LLC;CI...
# 10  Leemilt's Petroleum;Leemilt's Petroleum;Leemil...
#
#            lastmilestonedate  total_projects  has_centroid  \
# 5   2019-05-28T04:00:00.000Z           29013          True
# 6   2019-05-28T04:00:00.000Z           29013          True
# 8   2019-05-20T04:00:00.000Z           29013          True
# 9   2019-05-20T04:00:00.000Z           29013          True
# 10  2019-05-19T04:00:00.000Z           29013          True
#
#                                   center  \
# 5    [-73.959537931908,40.6789975203786]
# 6   [-73.9580891085031,40.6785645542978]
# 8     [-73.920328878287,40.677345947327]
# 9   [-73.9736549702216,40.5972231305137]
# 10  [-73.8676552720272,40.6831443832046]
#
#                                          ulurpnumbers
# 5                         ["C180042ZMK","N180043ZRK"]
# 6                         ["C160175ZMK","N160176ZRK"]
# 8   ["190160HAK","190161ZMK","190163HUK","N190162Z...
# 9                         ["C180164ZMK","N180165ZRK"]
# 10                                      ["190222ZMK"]

# %%
print("Number of Brooklyn ZAP applications: {}".format(zap_bk.shape[0]))
# Out:
# Number of Brooklyn ZAP applications: 4175

# %% [markdown]
# ### ZAP for Red Hook only

# %%
# Pull in the shapefile of the combined census tracts for Red Hook for spatial join
files = !ls data/created_data/rh_comb_tract
print(list(enumerate(files)))
# Out:
# [(0, 'rh_comb_tract.cpg'), (1, 'rh_comb_tract.dbf'), (2, 'rh_comb_tract.prj'), (3, 'rh_comb_tract.shp'), (4, 'rh_comb_tract.shx')]

# %%
# Census tracts for Red Hook
shp = files[3]
loc = 'data/created_data/rh_comb_tract/' + shp
rh_tracts = gpd.GeoDataFrame.from_file(loc)
rh_tracts.head()
# Out:
#   boro_code boro_ct201 boro_name cdeligibil  ct2010 ctlabel ntacode  GeoID  \
# 0         3    3008500  Brooklyn          E  008500      85    BK33   4005
#
#      shape_area   shape_leng  \
# 0  2.624914e+06  7950.931705
#
#                                             geometry
# 0  POLYGON ((-74.00485241669628 40.68566813081066...

# %%
f, ax = plt.subplots(figsize=(10,10))
rh_tracts.plot(alpha=1,linewidth=0.8,ax=ax,color='w',edgecolor='black')
plt.title("Red Hook", fontsize=20)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.show()

# %%
# Spatial join - to do
# zap_rh = gpd.tools.sjoin(zap_bk,rh_tracts)

# %% [markdown]
# # Google geocode

# %% [markdown]
# Because the ZAP application data pulled from the NYC Planning Labs website was missing latitude and longitude information for 8,415 applications, I will use Google's geocoding API feature to try and fill in that missing information.
#
# Big thanks to data scientist Shane Lynn for publishing his script that will execute batch geocoding queries. His script can be found at the following URL:
#
# https://www.shanelynn.ie/batch-geocoding-in-python-with-google-geocoding-api/#script-code
#
# Note that in order for the query and the next couple cells to run, you will need your own Google Maps geocoding API key saved in a text file called "google_api.txt." Do not include any other information in that file.

# %%
# Get a dataframe of ZAP applications missing the latitude and longitude for the project center
zap_ll_null = zap[zap['center'].str.contains('null')==True]

# %%
zap_ll_null.head()
# Out:
#       dcp_name dcp_ceqrnumber  \
# 1   P2017R0360      19DCP150R
# 2    2019M0149      19DCP110Y
# 17   2019R0264      19DCP130R
# 18  P2018M0038      03DCP031M
# 38   2019K0287            NaN
#
#                                       dcp_projectname  \
# 1                                    45 Douglas Court
# 2   Residential Tower Mechanical Voids Text Amendment
# 17                                 SS 217 Main Street
# 18     66 Hudson Boulevard Streetscape Text Amendment
# 38  Consolidation of ACS Division of Child Protection
#
#                                      dcp_projectbrief dcp_publicstatus_simp  \
# 1   This is a private application by Convery Inves...      In Public Review
# 2   The Department of City Planning (DCP) proposes...      In Public Review
# 17  This is a private application by Philese Black...             Completed
# 18  A private application for a text amendment to ...      In Public Review
# 38  This is a notice of intent by the New York Cit...             Completed
#
#       dcp_borough dcp_ulurp_nonulurp dcp_communitydistricts actiontypes  \
# 1   Staten Island              ULURP                   SI02       ZA;ZA
# 2       Manhattan              ULURP                   CY00          ZR
# 17  Staten Island          Non-ULURP                   SI03          RC
# 18      Manhattan          Non-ULURP                   MN04          ZR
# 38       Brooklyn          Non-ULURP                   BK02       PX;PX
#
#        dcp_certifiedreferred dcp_femafloodzonea dcp_femafloodzonecoastala  \
# 1   2019-04-03T04:00:00.000Z              False                     False
# 2   2019-01-28T19:22:12.000Z              False                     False
# 17  2019-04-26T17:50:39.000Z              False                     False
# 18  2018-12-17T05:00:00.000Z              False                     False
# 38  2019-03-20T18:05:22.000Z              False                     False
#
#    dcp_femafloodzoneshadedx dcp_femafloodzonev  \
# 1                     False              False
# 2                     False              False
# 17                    False              False
# 18                    False              False
# 38                    False              False
#
#                          applicants         lastmilestonedate  total_projects  \
# 1   Peter Calvanico;Peter Calvanico  2019-06-10T04:00:00.000Z           29013
# 2                               DCP  2019-06-03T04:00:00.000Z           29013
# 17                 Philese Blackler  2019-04-25T04:00:00.000Z           29013
# 18                   Tishman Speyer  2019-04-24T21:53:10.000Z           29013
# 38                         ACS;DCAS  2019-04-22T04:00:00.000Z           29013
#
#     has_centroid       center                 ulurpnumbers
# 1          False  [null,null]  ["N190308ZAR","N190310ZAR"]
# 2          False  [null,null]               ["N190230ZRY"]
# 17         False  [null,null]               ["N190269RCR"]
# 18         False  [null,null]               ["N190205ZRM"]
# 38         False  [null,null]               ["N190254PXK"]

# %%
# Form a list of addresses for geocoding:
addresses = (zap_ll_null['dcp_projectname'] + ', ' + zap_ll_null['dcp_borough'] + ', NY, US').tolist()

# %%
# Take a sample to show how the geocode will work
addresses_sample = addresses[:5]

# %%
addresses_sample
# Out:
# ['45 Douglas Court, Staten Island, NY, US',
#  'Residential Tower Mechanical Voids Text Amendment, Manhattan, NY, US',
#  'SS 217 Main Street, Staten Island, NY, US',
#  '66 Hudson Boulevard Streetscape Text Amendment, Manhattan, NY, US',
#  'Consolidation of ACS Division of Child Protection, Brooklyn, NY, US']

# %%
# To retrieve API key for following query
API_KEY = open('google_api.txt', 'r').readlines()[0][:] # api stored in seperate .txt file

# %%
# Function
def get_google_results(address, api_key=None, return_full_response=False):
    # Set up Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
# Create a list to hold results
results_sample = []
# Go through each address in turn
for address in addresses_sample:
    geocode_result = get_google_results(address, API_KEY)
    results_sample.append(geocode_result)

# %%
# Sample results
results_sample_df = pd.DataFrame(results_sample)
results_sample_df.head()
# Out:
#       accuracy                            formatted_address  \
# 0      ROOFTOP  45 Douglas Ct, Staten Island, NY 10304, USA
# 1  APPROXIMATE                 Manhattan, New York, NY, USA
# 2      ROOFTOP    217 Main St, Staten Island, NY 10307, USA
# 3      ROOFTOP        66 Hudson Blvd E, West, NY 10001, USA
# 4  APPROXIMATE                            Brooklyn, NY, USA
#
#                google_place_id  \
# 0  ChIJ8_sf4PZOwokRkHmQtiRNrvk
# 1  ChIJYeZuBI9YwokRjMDs_IEyCwo
# 2  ChIJe41FVZnKw4kRNZEBZ286_zg
# 3  ChIJSbI7fbNZwokRhr1NS-eDyHc
# 4  ChIJCSF8lBZEwokRhngABHRcdoI
#
#                                         input_string   latitude  longitude  \
# 0            45 Douglas Court, Staten Island, NY, US  40.608527 -74.091696
# 1  Residential Tower Mechanical Voids Text Amendm...  40.783060 -73.971249
# 2          SS 217 Main Street, Staten Island, NY, US  40.509931 -74.247232
# 3  66 Hudson Boulevard Streetscape Text Amendment...  40.755680 -74.000510
# 4  Consolidation of ACS Division of Child Protect...  40.678178 -73.944158
#
#    number_of_results postcode status  \
# 0                  1    10304     OK
# 1                  1              OK
# 2                  1    10307     OK
# 3                  1    10001     OK
# 4                  1              OK
#
#                                         type
# 0                             street_address
# 1  political,sublocality,sublocality_level_1
# 2                                    premise
# 3                             street_address
# 4  political,sublocality,sublocality_level_1

# %%
# Create a list to hold results
results = []
# Go through each address in turn
for address in addresses:
    geocode_result = get_google_results(address, API_KEY)
    results.append(geocode_result)

# %%
zap_geocode_done = pd.DataFrame(results)

# %%
zap_geocode_done.reset_index(drop=True, inplace=True)

# %%
zap_geocode_done = zap_geocode_done[['input_string', 'latitude', 'longitude']]

# %% [markdown]
# # Next steps
#
# * Run the geocode on all the applications missing latitude and longitude (this may take a while)
# * Once I have all the locations, I'll be able to spatially join them with our Red Hook shapefile
