# %% [markdown]
# # Employment analysis
#
# This is an analysis of employment in Brooklyn and NYC. Unfortunately, employment data could only be located at the county level but not at the neighborhood level (data was pulled from: https://www.bls.gov/cew/datatoc.htm). I looked around for other local or state-level data sources but didn't find anything that would let us hone in on Red Hook.
#
# I also did a quick analysis of the other geographic labor data available through QCEW ("CSVs By Area"). These data sets contained much more detailed information than seemed necessary at this time. If we wanted to pull more detailed data, we could do so.

# %% [markdown]
# ## Libraries

# %%
import urllib.request
import pandas as pd
import matplotlib.pylab as plt
from matplotlib import cm
import numpy as np
import itertools

# %% [markdown]
# ## Pulling data
#
# If you want to pull the original data and load it, you can uncomment and run the following cells.

# %%
# To get county data for 2010 to 2017
# for i in range(0,8):
#     url = 'https://data.bls.gov/cew/data/files/201{}/xls/201{}_all_county_high_level.zip'.format(i, i)
#     zip_file = 'all_county_high_level_201{}.zip'.format(i)
#     urllib.request.urlretrieve(url, zip_file)
#     !unzip $zip_file -d data/primary_source_data/qcew
#     for j in range(1, 5):
#         del_file = 'data/primary_source_data/qcew/allhlcn1{}{}.xlsx'.format(i, j)
#         !rm -r $del_file
#     !rm -r $zip_file

# %%
# # Since the data for 2018 is slightly different, manually pull it
# url_18 = 'https://data.bls.gov/cew/data/files/2018/xls/2018_all_county_high_level.zip'
# zip_file_18 = 'all_county_high_level_2018.zip'
# urllib.request.urlretrieve(url_18, zip_file_18)
# !unzip $zip_file_18 -d data/primary_source_data/qcew

# %%
# # Get the dfs for each year
# county_dfs = []
# for i in range(0,8):
#     temp_df = pd.read_excel('data/primary_source_data/qcew/allhlcn1{}.xlsx'.format(i))
#     county_dfs.append(temp_df)

# # Combine the data
# counties = pd.concat(county_dfs)

# # Filter down to NYC counties
# counties = counties[counties.St=='36']
# counties = counties[(counties.Cnty == 5) | (counties.Cnty == 47) | (counties.Cnty == 61) | \
#                     (counties.Cnty == 81) | (counties.Cnty == 85)]

# # Remove integers from the "Industry" for easier plotting
# counties.Industry = counties.Industry.str.replace('\d+', '').str.lstrip()
# counties.head()

# %%
# Uncomment to export the data again
# counties.to_csv('data/created_data/employment.csv', index=False)

# %% [markdown]
# ## All county data over time
#
# Pulling in and analyzing the cleaned data.

# %%
# Load the data from the file that was previously exported
counties = pd.read_csv('data/created_data/employment.csv')
counties.head()
# Out:
#    Area\nCode  St  Cnty  Own  NAICS  Year Qtr Area Type   St Name  \
# 0       36005  36   5.0    0     10  2010   A    County  New York
# 1       36005  36   5.0    1     10  2010   A    County  New York
# 2       36005  36   5.0    2     10  2010   A    County  New York
# 3       36005  36   5.0    3     10  2010   A    County  New York
# 4       36005  36   5.0    5     10  2010   A    County  New York
#
#                      Area           Ownership               Industry  \
# 0  Bronx County, New York       Total Covered  Total, all industries
# 1  Bronx County, New York  Federal Government  Total, all industries
# 2  Bronx County, New York    State Government  Total, all industries
# 3  Bronx County, New York    Local Government  Total, all industries
# 4  Bronx County, New York             Private  Total, all industries
#
#   Annual Average Status Code  Annual Average Establishment Count  \
# 0                        NaN                               16613
# 1                        NaN                                  73
# 2                        NaN                                  10
# 3                        NaN                                  12
# 4                        NaN                               16517
#
#                           2011              715026
#                           2012              727354
#                           2013              739715
#                           2014              746890
#                           2015              882669
#                           2016              793512
#                           2017              818270
#
#                                 Employment Location Quotient Relative to U.S.  \
# Area                      Year
# Bronx County, New York    2010                                          17.44
#                           2011                                          17.46
#                           2012                                          18.08
#                           2013                                          17.67
#                           2014                                          17.29
#                           2015                                          16.15
#                           2016                                          16.67
#                           2017                                          14.94
# Kings County, New York    2010                                          21.65
#                           2011                                          21.61
#                           2012                                          22.45
#                           2013                                          21.96
#                           2014                                          21.63
#                           2015                                          20.18
#                           2016                                          21.44
#                           2017                                          17.57
# New York County, New York 2010                                          18.28
#                           2011                                          18.19
#                           2012                                          18.42
#                           2013                                          18.37
#                           2014                                          18.39
#                           2015                                          18.65
#                           2016                                          19.40
#                           2017                                          18.25
# Queens County, New York   2010                                          20.88
#                           2011                                          20.81
#                           2012                                          21.60
#                           2013                                          21.35
#                           2014                                          21.47
#                           2015                                          19.56
#                           2016                                          20.59
#                           2017                                          17.65
# Richmond County, New York 2010                                          19.03
#                           2011                                          18.84
#                           2012                                          19.68
#                           2013                                          20.36
#                           2014                                          19.81
#                           2015                                          18.24
#                           2016                                          19.32
#                           2017                                          16.71
#
#                                 Total Wage Location Quotient Relative to U.S.
# Area                      Year
# Bronx County, New York    2010                                          16.81
#                           2011                                          16.71
#                           2012                                          17.04
#                           2013                                          16.95
#                           2014                                          17.04
#                           2015                                          15.99
#                           2016                                          16.19
#                           2017                                          15.28
# Kings County, New York    2010                                          19.49
#                           2011                                          19.80
#                           2012                                          20.31
#                           2013                                          20.56
#                           2014                                          20.74
#                           2015                                          19.50
#                           2016                                          20.40
#                           2017                                          17.91
# New York County, New York 2010                                          16.64
#                           2011                                          16.46
#                           2012                                          16.51
#                           2013                                          16.67
#                           2014                                          16.61
#                           2015                                          16.59
#                           2016                                          16.88
#                           2017                                          16.20
# Queens County, New York   2010                                          19.59
#                           2011                                          19.38
#                           2012                                          19.82
#                           2013                                          19.73
#                           2014                                          19.87
#                           2015                                          18.68
#                           2016                                          19.06
#                           2017                                          17.57
# Richmond County, New York 2010                                          18.64
#                           2011                                          18.44
#                           2012                                          19.32
#                           2013                                          19.78
#                           2014                                          19.44
#                           2015                                          18.34
#                           2016                                          18.80
#                           2017                                          17.04

# %%
# Brooklyn employment growth
print("{}%".format(round(counties[counties.Area=='Kings County, New York'].groupby(['Area','Year']).sum()\
                         .pct_change().reset_index()['Annual Average Employment'].values[1:].mean()*100, 3)))
# Out:
# 4.945%

# %% [markdown]
# ## Plotting
#
# First a line plot and then a stacked bar chart.

# %%
# To control font sizes
titles = 25
x_labels = 25
y_labels = 25
tick_size = 20

# Set up the plot
fig, axes = plt.subplots(3, 2, figsize=(25,20))
fig.suptitle("Comparison of Employment Across Counties", fontsize=30)

# Counties
cntys = list(counties.Cnty.unique())

# Plot
for i in range(len(cntys)):
    marker = itertools.cycle(('o', 'v', '+', 'P'))
    data = counties[(counties['Cnty']==cntys[i]) & (counties['Industry']!='Total, all industries')]
    for ind in data.Industry.unique():
        x = data[data.Industry==ind]['Year']
        y = data[data.Industry==ind]['Annual Average Employment']
        if i <= 2:
            axes[i, 0].plot(x, y, marker = next(marker), label = ind, markersize=12)
            axes[i, 0].set_title("Employment in {}".format(data['Area'].unique()[0]), \
                                      fontdict={'fontsize':titles})
            axes[i, 0].set_xlabel("Year", fontdict={'fontsize':x_labels})
            axes[i, 0].set_ylabel("Ann. Avg. Empl.", fontdict={'fontsize':y_labels})
            axes[i, 0].tick_params(labelsize=tick_size)
            
        else:
            axes[i-3, 1].plot(x, y, marker = next(marker), label = ind, markersize=12)
            axes[i-3, 1].set_title("Employment in {}".format(data['Area'].unique()[0]), \
                                      fontdict={'fontsize':titles})            
            axes[i-3, 1].set_xlabel("Year", fontdict={'fontsize':x_labels})
            axes[i-3, 1].set_ylabel("Ann. Avg. Empl.", fontdict={'fontsize':y_labels})
            axes[i-3, 1].tick_params(labelsize=tick_size)

# Add legend
handles, labels = axes[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower right', fontsize=20)

# Add padding
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.3, wspace=0.2)

# Remove unnecessary subplot
axes[2, 1].remove()

# %%
# To control font sizes
titles = 40
x_labels = 30
y_labels = 30
tick_size = 25

# Set up the plot
fig, axes = plt.subplots(3, 2, figsize=(30,30))
fig.suptitle("Comparison of Employment Across Counties", fontsize=30)

# Counties
cntys = list(counties.Cnty.unique())

# Plot
for i in range(len(cntys)):
    data = counties[counties.Cnty==cntys[i]][['Year','Industry','Annual Average Employment']]
    data = data[data['Industry']!='Total, all industries']
    data = data.pivot(index='Year', columns='Industry', values='Annual Average Employment')
    if i <= 2:
        data.plot.bar(stacked=True, ax=axes[i, 0])
        axes[i, 0].set_title("Employment in {}".format(counties['Area'].unique()[i]), \
                                  fontdict={'fontsize':titles})
        axes[i, 0].set_xlabel("Year", fontdict={'fontsize':x_labels})
        axes[i, 0].set_ylabel("Ann. Avg. Empl.", fontdict={'fontsize':y_labels})
        axes[i, 0].get_legend().remove()
        axes[i, 0].tick_params(labelsize=tick_size)


    else:
        data.plot.bar(stacked=True, ax=axes[i-3, 1])
        axes[i-3, 1].set_title("Employment in {}".format(counties['Area'].unique()[i]), \
                                  fontdict={'fontsize':titles})            
        axes[i-3, 1].set_xlabel("Year", fontdict={'fontsize':x_labels})
        axes[i-3, 1].set_ylabel("Ann. Avg. Empl.", fontdict={'fontsize':y_labels})
        axes[i-3, 1].get_legend().remove()
        axes[i-3, 1].tick_params(labelsize=tick_size)

# Add legend
handles, labels = axes[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower right', fontsize=30)

# Add padding
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.5, wspace=0.18)

# Remove unnecessary subplot
axes[2, 1].remove()

# %% [markdown]
# # Next steps:
#
# * Change the plots - subplot by industry (or higher level / groups of industries, no more than 5-6) and include data from all 5 boroughs in each group
# * Calculate the net job change (meaning the number of jobs gained or lost per industry per borough)
#     * See https://www1.nyc.gov/assets/planning/download/pdf/about/dcp-priorities/data-expertise/nyc-geography-jobs-0718.pdf
# * Figure out what to do with 2018 data - data is only availalbe for the first 3 quarters of 2018
