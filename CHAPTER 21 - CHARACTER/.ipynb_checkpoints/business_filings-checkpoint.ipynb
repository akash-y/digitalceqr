# %% [markdown]
# # Business Filings in NYC
#
# This notebook relies on data from the "Legally Operating Businesses" dataset posted on NYC Open data:
#
# https://data.cityofnewyork.us/Business/Legally-Operating-Businesses/w7w3-xahh
#
# It contains historical information on business filings in NYC including the business type and location.

# %%
import urllib.request
import pandas as pd
import geopandas as gpd
import shapely
from shapely.geometry import Polygon
from fiona.crs import from_epsg
import matplotlib.pylab as plt
import numpy as np
import copy

# %%
business_filings = pd.read_csv('data/primary_source_data/business_filings.csv')
business_filings.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   DCA License Number License Type License Expiration Date License Status  \
# 0        0959361-DCA     Business              03/31/2021         Active
# 1        1235988-DCA     Business              02/28/2021         Active
# 2        1453298-DCA   Individual              05/31/2019         Active
# 3        2049399-DCA     Business              12/31/2020         Active
# 4        2021443-DCA     Business              03/31/2021         Active
#
#   License Creation Date                     Industry  \
# 0            04/25/1997                       Garage
# 1            08/15/2006  Home Improvement Contractor
# 2            01/07/2013                    Locksmith
# 3            03/09/2017            Electronics Store
# 4            04/21/2015       Garage and Parking Lot
#
#                             Business Name Business Name 2 Address Building  \
# 0           PARKANLEX GARAGE COMPANY, LLC             NaN              115
# 1  JUNIOR'S IRONWORK & CONSTRUCTION, INC.             NaN            16927
# 2                         RAO, GARY PETER             NaN              NaN
# 3               CANAL ALARM DEVICES, INC.             NaN              387
# 4               O & A PARKING GARAGE INC.             NaN             1100
#
#   Address Street Name                    ...                     \
# 0           E 75TH ST                    ...
# 1         LIBERTY AVE                    ...
# 2                 NaN                    ...
# 3            CANAL ST                    ...
# 4        FRANKLIN AVE                    ...
#
#   Community Board Council District          BIN         BBL   NTA  \
# 0           108.0              4.0  1.04314e+06  1014100011  MN40
# 1           412.0             27.0        4e+06  4102180032  QN61
# 2             NaN              NaN          NaN         NaN   NaN
# 3           102.0              1.0  1.00294e+06  1002270004  MN24
# 4             NaN              NaN          NaN         NaN  BX35
#
#   Census Tract                                   Detail  Longitude   Latitude  \
# 0        128.0  Vehicle Spaces: 165, Bicycle Spaces: 17 -73.961625  40.772737
# 1        444.0                                      NaN -73.788915  40.703297
# 2          NaN                                      NaN        NaN        NaN
# 3         47.0                                      NaN -74.004791  40.721466
# 4        185.0   Vehicle Spaces: 36, Bicycle Spaces: 10        NaN        NaN
#
#                                    Location
# 0    (40.7727369020104, -73.96162515178469)
# 1   (40.70329689832498, -73.78891454010119)
# 2                                       NaN
# 3  (40.721465796925365, -74.00479091086221)
# 4                                       NaN
#
# [5 rows x 27 columns]

# %%
# Remove rows for filings with Address Borough listed as "Outside NYC"
nyc_filings = business_filings[business_filings['Address Borough']!='Outside NYC']

# %%
# Drop "Location" column since it is improperly formatted
nyc_filings.drop(['Location'], axis=1, inplace=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
print("Total number of business filings in all of NYC: {}".format(nyc_filings.shape[0]))
# Out:
# Total number of business filings in all of NYC: 184145

# %% [markdown]
# ## Grouping by date for NYC

# %%
# Convert creation date to datetime
nyc_filings['License Creation Date'] = pd.to_datetime(nyc_filings['License Creation Date'], \
                                                           format='%m/%d/%Y')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# All filings in NYC
filings_date_groups = nyc_filings.set_index('License Creation Date')
filings_date_groups.head()
# Out:
#                       DCA License Number License Type License Expiration Date  \
# License Creation Date
# 1997-04-25                   0959361-DCA     Business              03/31/2021
# 2006-08-15                   1235988-DCA     Business              02/28/2021
# 2013-01-07                   1453298-DCA   Individual              05/31/2019
# 2017-03-09                   2049399-DCA     Business              12/31/2020
# 2015-04-21                   2021443-DCA     Business              03/31/2021
#
#                       License Status                     Industry  \
# License Creation Date
# 1997-04-25                    Active                       Garage
# 2006-08-15                    Active  Home Improvement Contractor
# 2013-01-07                    Active                    Locksmith
# 2017-03-09                    Active            Electronics Store
# 2015-04-21                    Active       Garage and Parking Lot
#
#                                                 Business Name Business Name 2  \
# License Creation Date
# 1997-04-25                      PARKANLEX GARAGE COMPANY, LLC             NaN
# 2006-08-15             JUNIOR'S IRONWORK & CONSTRUCTION, INC.             NaN
# 2013-01-07                                    RAO, GARY PETER             NaN
# 2017-03-09                          CANAL ALARM DEVICES, INC.             NaN
# 2015-04-21                          O & A PARKING GARAGE INC.             NaN
#
#                       Address Building Address Street Name  \
# License Creation Date
# 1997-04-25                         115           E 75TH ST
# 2006-08-15                       16927         LIBERTY AVE
# 2013-01-07                         NaN                 NaN
# 2017-03-09                         387            CANAL ST
# 2015-04-21                        1100        FRANKLIN AVE
#
#                       Secondary Address Street Name    ...     Borough Code  \
# License Creation Date                                  ...
# 1997-04-25                                      NaN    ...              1.0
# 2006-08-15                                      NaN    ...              4.0
# 2013-01-07                                      NaN    ...              NaN
# 2017-03-09                                      NaN    ...              1.0
# 2015-04-21                                      NaN    ...              2.0
#
#                       Community Board Council District          BIN  \
# License Creation Date
# 1997-04-25                      108.0              4.0  1.04314e+06
# 2006-08-15                      412.0             27.0        4e+06
# 2013-01-07                        NaN              NaN          NaN
# 2017-03-09                      102.0              1.0  1.00294e+06
# 2015-04-21                        NaN              NaN          NaN
#
#                               BBL   NTA  Census Tract  \
# License Creation Date
# 1997-04-25             1014100011  MN40         128.0
# 2006-08-15             4102180032  QN61         444.0
# 2013-01-07                    NaN   NaN           NaN
# 2017-03-09             1002270004  MN24          47.0
# 2015-04-21                    NaN  BX35         185.0
#
#                                                         Detail  Longitude  \
# License Creation Date
# 1997-04-25             Vehicle Spaces: 165, Bicycle Spaces: 17 -73.961625
# 2006-08-15                                                 NaN -73.788915
# 2013-01-07                                                 NaN        NaN
# 2017-03-09                                                 NaN -74.004791
# 2015-04-21              Vehicle Spaces: 36, Bicycle Spaces: 10        NaN
#
#                         Latitude
# License Creation Date
# 1997-04-25             40.772737
# 2006-08-15             40.703297
# 2013-01-07                   NaN
# 2017-03-09             40.721466
# 2015-04-21                   NaN
#
# [5 rows x 25 columns]

# %%
# Grouping all filings by the month of the creation date and taking the count of each column
filings_count = filings_date_groups.resample('M').count()

# %%
f, ax = plt.subplots(figsize=(20,8))
filings_count[filings_count.index.year>=2000]['DCA License Number'].plot(alpha=1,linewidth=2,ax=ax)
plt.title("Count of Monthly Business Filings Since the Year 2000 in NYC", fontsize=25)
plt.xlabel("Year", fontsize=20)
plt.ylabel("Number of Business Filings per Month", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ## Business Filings for Brooklyn only

# %%
bk_df = nyc_filings[(nyc_filings['Address Borough']=='Brooklyn') | (nyc_filings['Address Borough']=='BROOKLYN')]

# %%
# All filings in NYC
bk_date_groups = bk_df.set_index('License Creation Date')
bk_date_groups.head()
# Out:
#                       DCA License Number License Type License Expiration Date  \
# License Creation Date
# 2018-05-24                   2071799-DCA     Business              02/28/2019
# 2008-06-16                   1289042-DCA     Business              12/31/2020
# 2013-07-11                   1469166-DCA     Business              02/28/2021
# 2017-06-30                   2055200-DCA     Business              12/31/2020
# 2016-04-15                   2036113-DCA     Business              03/31/2018
#
#                       License Status                     Industry  \
# License Creation Date
# 2018-05-24                  Inactive  Home Improvement Contractor
# 2008-06-16                    Active        Tobacco Retail Dealer
# 2013-07-11                    Active  Home Improvement Contractor
# 2017-06-30                    Active            Electronics Store
# 2016-04-15                  Inactive             Stoop Line Stand
#
#                                          Business Name Business Name 2  \
# License Creation Date
# 2018-05-24                            148 HUA HONG INC             NaN
# 2008-06-16                       NEW STAR TOBACCO INC.             NaN
# 2013-07-11             DEPENDABLE GLASS & MIRROR CORP.             NaN
# 2017-06-30                            METRO SULZ, INC.             NaN
# 2016-04-15                         YASMIN GROCERY CORP             NaN
#
#                       Address Building Address Street Name  \
# License Creation Date
# 2018-05-24                        2011           W 13TH ST
# 2008-06-16                        4524             5TH AVE
# 2013-07-11                         112             12TH ST
# 2017-06-30                        1450       ROCKAWAY PKWY
# 2016-04-15                        1436          MYRTLE AVE
#
#                       Secondary Address Street Name    ...     Borough Code  \
# License Creation Date                                  ...
# 2018-05-24                                      NaN    ...              3.0
# 2008-06-16                                      NaN    ...              3.0
# 2013-07-11                                      NaN    ...              3.0
# 2017-06-30                                      NaN    ...              3.0
# 2016-04-15                                      NaN    ...              3.0
#
#                       Community Board Council District          BIN  \
# License Creation Date
# 2018-05-24                      311.0             47.0   3.1908e+06
# 2008-06-16                      307.0             38.0  3.01157e+06
# 2013-07-11                      306.0             39.0  3.02307e+06
# 2017-06-30                      318.0             46.0        3e+06
# 2016-04-15                      304.0             37.0  3.07568e+06
#
#                               BBL   NTA  Census Tract  \
# License Creation Date
# 2018-05-24             3070930077  BK29         402.0
# 2008-06-16             3007470045  BK32          80.0
# 2013-07-11             3010260018  BK37         117.0
# 2017-06-30             3081840044  BK50         968.0
# 2016-04-15             3033080013  BK77         433.0
#
#                                                                   Detail  \
# License Creation Date
# 2018-05-24                                                           NaN
# 2008-06-16                                                           NaN
# 2013-07-11                                                           NaN
# 2017-06-30                                                           NaN
# 2016-04-15             Product Category: Fruits, Vegetables, Soft Dri...
#
#                        Longitude   Latitude
# License Creation Date
# 2018-05-24            -73.984430  40.597747
# 2008-06-16            -74.007600  40.647730
# 2013-07-11            -73.993829  40.670270
# 2017-06-30            -73.901928  40.644774
# 2016-04-15            -73.917197  40.698918
#
# [5 rows x 25 columns]

# %%
# Grouping all filings by the month of the creation date and taking the count of each column
bk_count = bk_date_groups.resample('M').count()

# %%
f, ax = plt.subplots(figsize=(20,8))
filings_count[filings_count.index.year>=2000]['DCA License Number'].plot(alpha=1,linewidth=2,ax=ax)
bk_count[bk_count.index.year>=2000]['DCA License Number'].plot(alpha=1,linewidth=2,ax=ax)
plt.title("Count of Monthly Business Filings Since the Year 2000 in Brooklyn and All of NYC", fontsize=25)
plt.xlabel("Year", fontsize=20)
plt.ylabel("Number of Business Filings per Month", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ## Business Filings for Red Hook only

# %%
# Pull in the shapefile of the combined census tracts for Red Hook for spatial join
files = !ls data/created_data/rh_comb_tract
print(list(enumerate(files)))
# Out:
# [(0, 'rh_comb_tract.cpg'), (1, 'rh_comb_tract.dbf'), (2, 'rh_comb_tract.prj'), (3, 'rh_comb_tract.shp'), (4, 'rh_comb_tract.shx')]

# %%
# Census tracts for Red Hook
shp = files[3]
loc = 'data/created_data/rh_comb_tract/' + shp
rh_tracts = gpd.GeoDataFrame.from_file(loc)
rh_tracts.head()
# Out:
#   boro_code boro_ct201 boro_name cdeligibil  ct2010 ctlabel ntacode  GeoID  \
# 0         3    3008500  Brooklyn          E  008500      85    BK33   4005
#
#      shape_area   shape_leng  \
# 0  2.624914e+06  7950.931705
#
#                                             geometry
# 0  POLYGON ((-74.00485241669628 40.68566813081066...

# %%
businesses_rh = copy.deepcopy(nyc_filings)

# %%
businesses_rh = businesses_rh[businesses_rh['Longitude'].notnull()]
businesses_rh['lonlat'] = list(zip(businesses_rh.Longitude, businesses_rh.Latitude))

# %%
businesses_rh = gpd.GeoDataFrame(businesses_rh)
businesses_rh.crs = from_epsg(4326)
businesses_rh['geometry'] = businesses_rh[['lonlat']].applymap(lambda x:shapely.geometry.Point(x))

# %%
# Match CRS
businesses_rh = businesses_rh.to_crs(epsg=4326)
rh_tracts = rh_tracts.to_crs(epsg=4326)

# %%
# Join with the Red Hook census tract to keep only business filings within the neighborhood
businesses_rh_sjoin = gpd.tools.sjoin(businesses_rh,rh_tracts)

# %%
# Plot
f, ax = plt.subplots(figsize=(10,10))
rh_tracts.plot(alpha=1,linewidth=0.8,ax=ax,color='w',edgecolor='black')
businesses_rh_sjoin.plot(alpha=1, linewidth=0.2,ax=ax,color='r',edgecolor='black',markersize=50)
plt.title("Business Filings Within Red Hook for All Time", fontsize=20)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.show()

# %%
# All Red Hook filings
rh_date_groups = businesses_rh_sjoin.set_index('License Creation Date')
rh_date_groups.head()
# Out:
#                       DCA License Number License Type License Expiration Date  \
# License Creation Date
# 2010-11-09                   1376498-DCA     Business              02/28/2021
# 2007-10-05                   1269827-DCA     Business              02/28/2019
# 2019-01-07                 2081179-1-DCA     Business              12/31/2019
# 2016-06-23                   2039389-DCA     Business              02/28/2021
# 2013-09-23                   1474193-DCA     Business              02/28/2021
#
#                       License Status                     Industry  \
# License Creation Date
# 2010-11-09                    Active  Home Improvement Contractor
# 2007-10-05                  Inactive  Home Improvement Contractor
# 2019-01-07                    Active        Tobacco Retail Dealer
# 2016-06-23                    Active  Home Improvement Contractor
# 2013-09-23                    Active  Home Improvement Contractor
#
#                                              Business Name Business Name 2  \
# License Creation Date
# 2010-11-09                               A T CONCEPT, INC.             NaN
# 2007-10-05                          PREMIUM MILLWORK, INC.             NaN
# 2019-01-07                               MP LORRAINE CORP.             NaN
# 2016-06-23                                CLEARVIEW SM INC             NaN
# 2013-09-23             360 INTERIOR CONCEPT HOLDINGS CORP.             NaN
#
#                       Address Building Address Street Name  \
# License Creation Date
# 2010-11-09                         601            COURT ST
# 2007-10-05                          43           COFFEY ST
# 2019-01-07                          58         LORRAINE ST
# 2016-06-23                         199             BUSH ST
# 2013-09-23                         360        HAMILTON AVE
#
#                       Secondary Address Street Name     ...      boro_code  \
# License Creation Date                                   ...
# 2010-11-09                                      NaN     ...              3
# 2007-10-05                                      NaN     ...              3
# 2019-01-07                                      NaN     ...              3
# 2016-06-23                                      NaN     ...              3
# 2013-09-23                                      NaN     ...              3
#
#                       boro_ct201 boro_name cdeligibil  ct2010  ctlabel  \
# License Creation Date
# 2010-11-09               3008500  Brooklyn          E  008500       85
# 2007-10-05               3008500  Brooklyn          E  008500       85
# 2019-01-07               3008500  Brooklyn          E  008500       85
# 2016-06-23               3008500  Brooklyn          E  008500       85
# 2013-09-23               3008500  Brooklyn          E  008500       85
#
#                        ntacode  GeoID    shape_area   shape_leng
# License Creation Date
# 2010-11-09                BK33   4005  2.624914e+06  7950.931705
# 2007-10-05                BK33   4005  2.624914e+06  7950.931705
# 2019-01-07                BK33   4005  2.624914e+06  7950.931705
# 2016-06-23                BK33   4005  2.624914e+06  7950.931705
# 2013-09-23                BK33   4005  2.624914e+06  7950.931705
#
# [5 rows x 38 columns]

# %%
# Grouping all filings by the month of the creation date and taking the count of each column
rh_count = rh_date_groups.resample('M').count()

# %%
f, ax = plt.subplots(figsize=(20,8))
bk_count[bk_count.index.year>=2000]['DCA License Number'].plot(alpha=1,linewidth=2,ax=ax)
rh_count[rh_count.index.year>=2000]['DCA License Number'].plot(alpha=1,linewidth=2,ax=ax,label='Red Hook')
plt.title("Count of Monthly Business Filings Since the Year 2000 in Red Hook and NYC", fontsize=25)
plt.xlabel("Year", fontsize=20)
plt.ylabel("Number of Business Filings per Month (Log)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Descriptive stats
#
# This data set is somewhat confusing because it includes the information for vendors across the country who have filed to operate in NYC. So the address information in this data set includes other locations outside NYC. It may be difficult to establish exactly how many business filings are related to Red Hook.
#
# For now, I will use a simple spatial join with our combined Red Hook cesus tracts to get an initial sense of the number of business filings within Red Hook.

# %%
# Number of rows missing borough info
print(nyc_filings['Address Borough'].isnull().sum())
# Out:
# 70414

# %%
# Number of rows missing city info (note that this column is less useful since it includes places beyond NYC)
print(nyc_filings['Address City'].isnull().sum())
# Out:
# 710

# %%
# Number of rows missing lat lon
print(nyc_filings['Longitude'].isnull().sum())
print(nyc_filings['Latitude'].isnull().sum())
# Out:
# 70523
# 70523

# %% [markdown]
# ## Business filings by industry

# %%
# All unique industry names for filings across NYC
industries = set(nyc_filings['Industry'].values)
industries
# Out:
# {'Amusement Arcade',
#  'Amusement Device Permanent',
#  'Amusement Device Portable',
#  'Amusement Device Temporary',
#  'Auction House Premises',
#  'Auctioneer',
#  'Bingo Game Operator',
#  'Booting Company',
#  'Cabaret',
#  'Car Wash',
#  'Catering Establishment',
#  'Commercial Lessor',
#  'Dealer In Products',
#  'Debt Collection Agency',
#  'Electronic & Appliance Service',
#  'Electronic Cigarette Dealer',
#  'Electronics Store',
#  'Employment Agency',
#  'Games of Chance',
#  'Gaming Cafe',
#  'Garage',
#  'Garage and Parking Lot',
#  'General Vendor',
#  'General Vendor Distributor',
#  'Home Improvement Contractor',
#  'Home Improvement Salesperson',
#  'Horse Drawn Cab Owner',
#  'Horse Drawn Driver',
#  'Laundries',
#  'Laundry',
#  'Laundry Jobber',
#  'Locksmith',
#  'Locksmith Apprentice',
#  'Motion Picture Projectionist',
#  'Newsstand',
#  'Parking Lot',
#  'Pawnbroker',
#  'Pedicab Business',
#  'Pedicab Driver',
#  'Pool or Billiard Room',
#  'Process Server Individual',
#  'Process Serving Agency',
#  'Scale Dealer Repairer',
#  'Scrap Metal Processor',
#  'Secondhand Dealer - Auto',
#  'Secondhand Dealer - Firearms',
#  'Secondhand Dealer - General',
#  'Sidewalk Cafe',
#  'Sightseeing Bus',
#  'Sightseeing Guide',
#  'Special Sale',
#  'Stoop Line Stand',
#  'Storage Warehouse',
#  'Ticket Seller',
#  'Ticket Seller Business',
#  'Tobacco Retail Dealer',
#  'Tow Truck Company',
#  'Tow Truck Driver',
#  'Tow Truck Exemption'}

# %%
# All unique industry names for filings in Red Hook
rh_industries = set(businesses_rh['Industry'].values)
rh_industries
# Out:
# {'Amusement Arcade',
#  'Amusement Device Permanent',
#  'Amusement Device Portable',
#  'Amusement Device Temporary',
#  'Auction House Premises',
#  'Bingo Game Operator',
#  'Booting Company',
#  'Cabaret',
#  'Car Wash',
#  'Catering Establishment',
#  'Commercial Lessor',
#  'Dealer In Products',
#  'Debt Collection Agency',
#  'Electronic & Appliance Service',
#  'Electronic Cigarette Dealer',
#  'Electronics Store',
#  'Employment Agency',
#  'Games of Chance',
#  'Gaming Cafe',
#  'Garage',
#  'Garage and Parking Lot',
#  'General Vendor Distributor',
#  'Home Improvement Contractor',
#  'Horse Drawn Cab Owner',
#  'Laundries',
#  'Laundry',
#  'Laundry Jobber',
#  'Newsstand',
#  'Parking Lot',
#  'Pawnbroker',
#  'Pedicab Business',
#  'Pool or Billiard Room',
#  'Process Serving Agency',
#  'Scale Dealer Repairer',
#  'Scrap Metal Processor',
#  'Secondhand Dealer - Auto',
#  'Secondhand Dealer - Firearms',
#  'Secondhand Dealer - General',
#  'Sidewalk Cafe',
#  'Sightseeing Bus',
#  'Special Sale',
#  'Stoop Line Stand',
#  'Storage Warehouse',
#  'Ticket Seller Business',
#  'Tobacco Retail Dealer',
#  'Tow Truck Company',
#  'Tow Truck Exemption'}

# %%
def industry_group_maker(industry_list):
    industry_dfs = {}
    for industry in industry_list:
        temp_df = businesses_rh[businesses_rh['Industry']==industry]
        temp_df = temp_df.set_index('License Creation Date')
        temp_df = temp_df.resample('M').count()
        industry_dfs[industry] = industry_dfs.get(industry, temp_df)
    return industry_dfs

# %%
# Get all the individualized industry dataframes for Red Hook
all_rh_industry_dfs = industry_group_maker(rh_industries)

# %%
# Set earliest year to view:
y = 2010
f, ax = plt.subplots(figsize=(20,8))
for k,v in all_rh_industry_dfs.items():
    v[v.index.year>=y]['DCA License Number'].plot(alpha=1,linewidth=2,ax=ax,label=k)
plt.title("Monthly Business Filings By Industry Since {} in Red Hook".format(year), fontsize=25)
plt.xlabel("Year", fontsize=20)
plt.ylabel("Number of Filings for Garages per Month", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1))
plt.show()

# %% [markdown]
# # Next steps
#
# * RH - BK comparison: normalize to per capita
# * Industry aggregation: try to use the methodology of the QCEW;
#     * Try to investigate the QCEW data itself (see Dana's nb) - that data is by county so check if it’s relevant to our analysis.
#     * US Labor Dept. QCEW data: https://www.bls.gov/cew/cewover.htm#Data_Available
#     * You may also want to refer to this: https://www.bls.gov/cew/bls_naics/v1/bls_naics_app.htm#tab=search&naics=2012&keyword=%22car%22&searchType=indexes&filter=6_filter&sort=text_asc&resultIndex=0
# * Narrow down the business filings
# * Deal with missing latitude and longitude
